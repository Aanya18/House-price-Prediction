# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv("/kaggle/input/housedata/data.csv")

# Printing first 5 records of the dataset
print(dataset.head(5))



dataset.head()

# %%
dataset.info()

# %%
dataset.describe()

# %%
dataset.columns

# %%
sns.pairplot(dataset)

# %%
from datetime import datetime

date_string = '2014-05-02 00:00:00'
date_format = "%Y-%m-%d %H:%M:%S"

try:
    date_object = datetime.strptime(date_string, date_format)
    print(date_object)
except ValueError as e:
    print(f"Error: {e}")

# %%
sns.heatmap(dataset.corr(),annot=True)

# %%
x = dataset( 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
       'statezip', 'country')
y = dataset('price')

from sklearn.model_selection import train_test_spilt

x_train,x_test, y_train,y_test = train_test_spilt(x,y,test_size=0.40,random_state=101)

# %%
x_train

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)

# %%
coeff_df = pd.DataFrame(lm.coef_,x.columns,columns=['cofficient'])

# %%
coeff_df


predictions = lm.predict(x_test)


plt.scatter(y_test,predictions)


sns.distplot((y_test-predictions),bins=50);
